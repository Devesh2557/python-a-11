# %%
# Random Forest ----> Supervised Machine learning model --->
# (a). Numerical ---> Random ForestRegressor ---->Backend> 100 D.T.--> MSE-->Final output
#(b). Categorical---> Random ForestClassifier --->Backend --> 100 D.T. --->
# 70 yes, 30 No ---> Final output based on majority (yes)
 
# ensemble:- multiple weaklearners(dt) ko combine krke ek model banana

# %%
# Random Forest Classifier

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('covid_toy.csv')
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['gender'] = lb.fit_transform(df['gender'])
df['cough'] = lb.fit_transform(df['cough'])
df['city'] = lb.fit_transform(df['city'])
df['has_covid'] = lb.fit_transform(df['has_covid'])

# %%
df.head(1)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train , y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.45

# %%
# RandomForestRegressor

# %%
df = pd.read_csv('insurance.csv')
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
# df.isnull().sum()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker'] = lb.fit_transform(df['smoker'])
df['region'] = lb.fit_transform(df['region'])

# %%
df.head(1)
# Out:
#    age  sex   bmi  children  smoker  region    charges
# 0   19    0  27.9         0       1       3  16884.924

# %%
x=df.drop(columns = ['charges'])
y = df['charges']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.8616794737486747
